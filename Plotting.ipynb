# %%
import exploration
import feature_extraction
from galaxy_plotting import plot_projection

from sklearn import (manifold, datasets, decomposition, ensemble, lda, random_projection)

import mpld3
mpld3.enable_notebook()

# %%
solutions = exploration.get_reduced_solutions()
(X, y) = exploration.extract_features(solutions.index, feature_extraction.raw_all)
# Out:
# Loading: output_data/raw_all/feature_vectors_training

# %%
rp = random_projection.SparseRandomProjection(n_components=2)
X_random = rp.fit_transform(X)
plot_projection(X_random, y)

# %%
X_pca = decomposition.PCA(n_components=2, whiten=True).fit_transform(X)
plot_projection(X_pca, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a2f190a33fab> in <module>()
#       1 X_pca = decomposition.PCA(n_components=2, whiten=True).fit_transform(X)
# ----> 2 plot_projection(X_pca)
#
# TypeError: plot_projection() takes exactly 2 arguments (1 given)

# %%
X_iso = manifold.Isomap(n_neighbors=1, n_components=2).fit_transform(X)
plot_projection(X_iso, y)

# %%
clf = manifold.LocallyLinearEmbedding(n_neighbors=1, n_components=2, eigen_solver='dense')
X_lle = clf.fit_transform(X)
plot_projection(X_lle, y)
